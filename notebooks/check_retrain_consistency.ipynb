# %%
import sys
import pandas as pd
import pickle
sys.path.append('../twc_api/')
import boto3
import json
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
session = boto3.Session(profile_name='twc')
s3 = session.resource('s3')

# %%
from api.utils.transformers import *
from api.utils.aws import *

# %%
from scipy.stats import spearmanr
from sklearn.ensemble import ExtraTreesRegressor

# %%
ConsolidateTablesTransformer(count_encode=False)

# %% [markdown]
# # First recreate the model we've been using to date

# %% [markdown]
# ### Generate Training Data

# %%
generator = TrainingDataGenerator('../../Welcome-Centre-DataCorps-Data/ClientDatabaseStructure.mdb.sqlite')
training_data = generator.get_training_data(limit=100000)

# %%
json_tables = {k: v.to_json(orient='records') for k, v in training_data.items()}

# %% [markdown]
# ### Build your Transformer and Choose Features

# %%
features_to_split = []

transformer = TransformerPipeline([
                        ConsolidateTablesTransformer(count_encode=False),
                        AddFutureReferralTargetFeatures(),
                        TimeFeatureTransformer(break_length=28),
                        SplitCurrentAndEverTransformer(['referralissue_', 
                                                       'referraldomesticcircumstances_',
                                                        'referralreason_', 'referralbenefit_'])
                                    ], aligner=AlignFeaturesToColumnSchemaTransformer())

X, y, referral_table = transformer.fit_transform(training_data)

X = X.fillna(0)

# %%
X_train = X[X.index < 13500]
X_test = X[X.index >= 13500]
y_train = y.loc[X_train.index]
y_test = y.loc[X_test.index]

# %% [markdown]
# # Build a model

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
et = ExtraTreesRegressor(n_jobs=-1, n_estimators=500)
et.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#           max_features='auto', max_leaf_nodes=None,
#           min_impurity_decrease=0.0, min_impurity_split=None,
#           min_samples_leaf=1, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#           oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# # Evaluate model

# %%
y_pred = pd.Series(et.predict(X_test), X_test.index)

# %%
test_referral_table = referral_table.loc[X_test.index]

# %%
def get_scores_per_window(x, y, group, threshold=0.5):
    corr = spearmanr(x, y)[0]
    mu_a = x.groupby(group).mean()
    mu_p = y.groupby(group).mean()
    mu_a_top = mu_a[mu_a.rank(ascending=False) / len(mu_a) < threshold]
    mu_p_top = mu_p[mu_p.rank(ascending=False) / len(mu_p) < threshold]
    overlap = mu_p_top.index.isin(mu_a_top.index).mean()
    return pd.Series([corr, overlap], index=['spearman', 'overlap'])

# %%
def evaluate_average_weekly_rank_correlation(test_referral_table, y_test, y_pred):
    grouped_y = test_referral_table.assign(y=y_test, pred=y_pred).set_index('referral_referraltakendate')\
        .groupby([pd.TimeGrouper('1W'), 'client_clientid'])['y'].mean()
    grouped_pred_y = test_referral_table.assign(y=y_test, pred=y_pred).set_index('referral_referraltakendate')\
        .groupby([pd.TimeGrouper('1W'), 'client_clientid'])['pred'].mean()
    time_grouped = pd.concat([grouped_y, grouped_pred_y], axis=1)
    return time_grouped.reset_index().groupby(['referral_referraltakendate']).\
        apply(lambda k: get_scores_per_window(k['y'], k['pred'], k['client_clientid'])).dropna().mean()

# %%
evaluate_average_weekly_rank_correlation(test_referral_table, y_test, y_pred)
# Out:
# /Users/davidsykes/.virtualenvs/twc/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: pd.TimeGrouper is deprecated and will be removed; Please use pd.Grouper(freq=...)
#
# /Users/davidsykes/.virtualenvs/twc/lib/python3.5/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.TimeGrouper is deprecated and will be removed; Please use pd.Grouper(freq=...)
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/davidsykes/.virtualenvs/twc/lib/python3.5/site-packages/numpy/lib/function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/davidsykes/.virtualenvs/twc/lib/python3.5/site-packages/numpy/lib/function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# /Users/davidsykes/.virtualenvs/twc/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/davidsykes/.virtualenvs/twc/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/davidsykes/.virtualenvs/twc/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# spearman    0.500569
# overlap     0.665357
# dtype: float64

# %%
referral_table[referral_table['client_clientid'].isnull()]
# Out:
# Empty DataFrame
# Columns: [referral_statusid, referral_referralonhold, referral_referraltakendate, referral_referralreadydate, referral_referralcollecteddate, referral_referralworkerid, referral_referralhandedworkerid, referral_clientid, referral_partnername, referral_partnerid, referral_dependantdetails, referral_ethnicityid, referral_addresslocalityid, referral_addresstypeid, referral_referralagencyid, referral_referralagencyworkername, referral_referralagencytelephonenumber, referral_dietaryextranotes, referral_referralnotes, referral_updatetimestamp, client_clientid, reference_date, futurereferraltargetfeature_futurereferralcount, futurereferraltargetfeature_futurereferralscore, futurereferraltargetfeature_futurereferralgaps, timefeature_referralnumber, timefeature_burstnumber, timefeature_totalreferralsforclient]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# # Try and recreate the same using the auto-retrain logic

# %%
from api.resources.retrain import train_model_from_json
from api.resources.retrain import construct_full_tables

# %%
def process_referral_table(referral_table):
    referral_table['referraltakendate'] = pd.to_datetime(referral_table['referraltakendate'])
    referral_table = referral_table.set_index('referralinstanceid')
    referral_table = referral_table.add_prefix('referral_')
    return referral_table

process_referral_table(tables['referral'])
# Out:
#                    referral_addresslocalityid referral_addresstypeid  \
# referralinstanceid
# 12                                          6                      4
# 13                                          6                      1
# 2631                                        6                      1
# 2733                                        6                      1
# 2873                                        6                      1
# 14956                                       6                      4
# 15293                                     NaN                      4
# 15739                                     NaN                      2
# 18                                         11                      1
# 9083                                       11                      1
# 20                                         30                      1
# 21                                         30                      1
# 1620                                       30                      1
# 5096                                       30                      1
# 10525                                      30                      1
# 29                                         85                      1
# 30                                         85                      1
# 31                                         85                      1
# 4155                                       85                      1
# 7256                                       85                      1
# 9619                                       85                      1
# 11338                                      11                      1
# 12374                                      11                      1
# 14023                                     NaN                      3
# 14080                                     NaN                      4
# 14988                                     NaN                      1
# 15302                                     133                      1
# 15532                                     133                      1
# 41                                        NaN                      4
# 1623                                      NaN                      4
# ...                                       ...                    ...
# 23582                                      37                      1
# 23596                                       6                      1
# 23601                                     151                      1
# 23603                                    None                      2
# 23604                                     111                      1
# 24183                                     111                      1
# 24468                                     111                      1
# 25461                                     111                      1
# 23610                                      37                   None
# 23621                                    None                   None
# 23622                                    None                      7
# 23633                                    None                   None
# 23779                                    None                   None
# 23637                                    None                      5
# 23661                                      93                      1
# 23667                                      17                      1
# 23669                                      30                   None
# 23680                                      75                      1
# 23687                                     NaN                      2
# 23921                                     NaN                    NaN
# 24733                                     NaN                    NaN
# 24907                                      11                    NaN
# 24925                                      11                    NaN
# 24994                                      11                    NaN
# 25366                                     NaN                    NaN
# 25432                                     NaN                    NaN
# 25574                                     NaN                    NaN
# 25626                                     NaN                    NaN
# 25855                                     NaN                    NaN
# 23709                                      76                      2
#
#                     referral_clientid  referral_dependantnumber  \
# referralinstanceid
# 12                                 10                         0
# 13                                 10                         0
# 2631                               10                         0
# 2733                               10                         0
# 2873                               10                         0
# 14956                              10                         0
# 15293                              10                         0
# 15739                              10                         0
# 18                                 13                         2
# 9083                               13                         2
# 20                                 15                         1
# 21                                 15                         1
# 1620                               15                         1
# 5096                               15                         1
# 10525                              15                         1
# 29                                 18                         0
# 30                                 18                         0
# 31                                 18                         0
# 4155                               18                         0
# 7256                               18                         0
# 9619                               18                         0
# 11338                              18                         0
# 12374                              18                         0
# 14023                              18                         0
# 14080                              18                         0
# 14988                              18                         0
# 15302                              18                         0
# 29                                             NaN
# 30                                             NaN
# 31                                             NaN
# 4155                                             1
# 7256                                             5
# 9619                                            13
# 11338                                            1
# 12374                                           13
# 14023                                            1
# 14080                                            1
# 14988                                           26
# 15302                                            1
# 15532                                           26
# 41                                             NaN
# 1623                                             7
# ...                                            ...
# 23582                                           26
# 23596                                           26
# 23601                                           26
# 23603                                           26
# 23604                                           26
# 24183                                           26
# 24468                                           26
# 25461                                           26
# 23610                                         None
# 23621                                           26
# 23622                                         None
# 23633                                           26
# 23779                                           26
# 23637                                           26
# 23661                                           26
# 23667                                           26
# 23669                                           26
# 23680                                           26
# 23687                                           26
# 23921                                           26
# 24733                                           26
# 24907                                           26
# 24925                                           26
# 24994                                           26
# 25366                                           26
# 25432                                           26
# 25574                                           26
# 25626                                           26
# 25855                                          NaN
# 23709                                           26
#
#                    referral_referralpreparedworkerid  \
# referralinstanceid
# 12                                               NaN
# 13                                               NaN
# 2631                                               7
# 2733                                               7
# 2873                                               7
# 14956                                             26
# 15293                                              1
# 15739                                             26
# 18                                               NaN
# 9083                                               1
# 20                                               NaN
# 21                                               NaN
# 1620                                             NaN
# 5096                                               1
# 10525                                              3
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 4155                                               1
# 7256                                               5
# 9619                                              13
# 11338                                              1
# 12374                                             13
# 14023                                              1
# 14080                                              1
# 14988                                             26
# 15302                                              1
# 15532                                             26
# 41                                               NaN
# 1623                                             NaN
# ...                                              ...
# 23582                                             26
# 23596                                             26
# 23601                                             26
# 23603                                             26
# 23604                                             26
# 24183                                             26
# 24468                                             26
# 25461                                             26
# 23610                                             34
# 23621                                             26
# 23622                                              1
# 23633                                             26
# 23779                                             26
# 23637                                             26
# 23661                                             26
# 23667                                             26
# 23669                                             26
# 23680                                             26
# 23687                                             26
# 23921                                             26
# 24733                                             26
# 24907                                             26
# 24925                                             26
# 24994                                             26
# 25366                                             26
# 25432                                             26
# 25574                                             26
# 25626                                             26
# 25855                                            NaN
# 23709                                             26
#
#                    referral_referralreadydate referral_referraltakendate  \
# referralinstanceid
# 12                          01/13/14 00:00:00        2014-01-13 00:00:00
# 13                          02/03/14 00:00:00        2014-02-03 00:00:00
# 2631                        06/09/14 15:31:00        2014-06-09 15:31:00
# 2733                        06/16/14 15:46:00        2014-06-16 15:46:00
# 2873                        06/23/14 16:42:00        2014-06-23 16:42:00
# 14956                       10/18/16 13:06:00        2016-10-18 11:24:00
# 15293                       11/08/16 16:46:00        2016-11-08 12:32:00
# 15739                       12/02/16 15:29:00        2016-12-02 14:09:00
# 18                          02/05/14 00:00:00        2014-02-05 00:00:00
# 9083                        09/11/15 00:00:00        2015-09-11 10:25:00
# 20                          01/14/14 00:00:00        2014-01-14 00:00:00
# 21                          03/12/14 00:00:00        2014-03-12 00:00:00
# 1620                        04/02/14 15:32:00        2014-04-02 00:00:00
# 5096                        11/25/14 16:51:00        2014-11-25 09:57:00
# 10525                       12/11/15 15:53:00        2015-12-11 13:05:00
# 29                          02/10/14 00:00:00        2014-02-10 00:00:00
# 30                          02/19/14 00:00:00        2014-02-19 00:00:00
# 31                          03/11/14 00:00:00        2014-03-11 00:00:00
# 4155                        09/19/14 16:58:00        2014-09-19 10:39:00
# 7256                        04/22/15 00:00:00        2015-04-22 13:00:00
#
# [21079 rows x 16 columns]

# %%
referral_table[referral_table['referral_clientid']==3013]
# Out:
#        referral_statusid referral_referralonhold referral_referraltakendate  \
# 6126                   3                       0        2015-01-20 11:39:00
# 6923                   3                       0        2015-03-13 12:05:00
# 7250                   3                       0        2015-04-08 12:35:00
# 7370                   3                       0        2015-04-16 15:50:00
# 7447                   3                       0        2015-04-22 15:51:00
# 7866                   3                       0        2015-05-26 15:59:00
# 8014                   3                       0        2015-06-09 15:20:00
# 9427                   3                       0        2015-09-29 12:23:00
# 10862                  3                       0        2016-01-04 12:06:00
# 11271                  3                       0        2016-01-29 16:10:00
# 11621                  3                       0        2016-02-23 15:27:00
#
#       referral_referralreadydate referral_referralcollecteddate  \
# 6126           01/20/15 16:04:00              01/20/15 16:04:00
# 6923           03/13/15 17:35:00              03/13/15 17:35:00
# 7250           04/08/15 15:30:00              04/08/15 15:30:00
# 7370           04/16/15 16:06:00              04/16/15 16:06:00
# 7447           04/22/15 00:00:00              04/22/15 00:00:00
# 7866           05/26/15 16:44:00              05/26/15 16:44:00
# 8014           06/09/15 17:08:00              06/09/15 17:08:00
# 9427           09/29/15 16:13:00              09/29/15 16:14:00
# 10862          01/04/16 16:41:00              01/04/16 16:41:00
# 11271          01/29/16 16:30:00              01/29/16 16:30:00
# 11621          02/23/16 16:42:00              02/23/16 16:42:00
#
#        referral_referralworkerid  referral_referralhandedworkerid  \
# 6126                           1                              1.0
# 6923                           6                             13.0
# 7250                          10                              5.0
# 7370                           5                              5.0
# 7447                          13                              5.0
# 7866                           5                              1.0
# 8014                           1                              1.0
# 9427                           6                              1.0
# 10862                          1                              1.0
# 11271                         13                              1.0
# 11621                          6                              1.0
#
#        referral_clientid referral_partnername  referral_partnerid  \
# 6126                3013                 None                 NaN
# 6923                3013                 None                 NaN
# 7250                3013                 None                 NaN
# 7370                3013                 None                 NaN
# 7447                3013                 None                 NaN
# 7866                3013                 None                 NaN
# 8014                3013                 None                 NaN
# 9427                3013                 None                 NaN
# 10862               3013                 None                 NaN
# 11271               3013                 None                 NaN
# 11621               3013                 None                 NaN
#
#                       ...                  \
# 6126                  ...
# 6923                  ...
# 7250                  ...
# 7370                  ...
# 7447                  ...
# 7866                  ...
# 8014                  ...
# 9427                  ...
# 10862                 ...
# 11271                 ...
# 11621                 ...
#
#                                   referral_referralnotes  \
# 6126   <NAME> is sofa surfing and having to use her b...
# 6923   Came off JSA to do a job in Manchester but cou...
# 7250   Hannah has  been homeless and had to flee from...
# 7370                                        New tenancy.
# 7447   Hannah has recieved a letter of "doubt" regard...
# 7866   Hannah has had no income since april, there wa...
# 8014   hannah was on a sanction and borrowed money of...
# 9427   Had to pay family debts which has left her wit...
# 10862  had a claim in for UC due to the fact she is p...
# 11271  Benefits have been stopped pending receipt of ...
# 11621  H is pregnant and has applied for JSA she expe...
#
#        referral_updatetimestamp  client_clientid  reference_date  \
# 6126          01/20/15 16:04:23           3013.0             NaT
# 6923          03/13/15 17:35:11           3013.0             NaT
# 7250          04/08/15 15:30:04           3013.0             NaT
# 7370          04/16/15 16:06:12           3013.0             NaT
# 7447          04/23/15 10:38:24           3013.0             NaT
# 7866          05/26/15 16:44:35           3013.0             NaT
# 8014          06/09/15 17:08:35           3013.0             NaT
# 9427          09/29/15 16:14:00           3013.0             NaT
# 10862         01/04/16 16:41:40           3013.0             NaT
# 11271         01/29/16 16:30:44           3013.0             NaT
# 11621         02/23/16 16:42:53           3013.0             NaT
#
#        futurereferraltargetfeature_futurereferralcount  \
# 6126                                               8.0
# 6923                                               9.0
# 7250                                               8.0
# 7370                                               7.0
# 7447                                               6.0
# 7866                                               5.0
# 8014                                               4.0
# 9427                                               3.0
# 10862                                              2.0
# 11271                                              1.0
# 11621                                              0.0
#
#       futurereferraltargetfeature_futurereferralscore  \
# 6126                                         0.076712
# 6923                                         0.115068
# 7250                                         0.095890
# 7370                                         0.076712
# 7447                                         0.057534
# 7866                                         0.057534
# 8014                                         0.038356
# 9427                                         0.038356
# 10862                                        0.038356
# 11271                                        0.019178
# 11621                                        0.000000
#
#       futurereferraltargetfeature_futurereferralgaps  \
# 6126                                             4.0
# 6923                                             3.0
# 7250                                             3.0
# 7370                                             3.0
# 7447                                             3.0
# 7866                                             2.0
# 8014                                             2.0
# 9427                                             1.0
# 10862                                            0.0
# 11271                                            0.0
# 11621                                            0.0
#
#       timefeature_referralnumber timefeature_burstnumber  \
# 6126                         1.0                     1.0
# 6923                         2.0                     2.0
# 7250                         3.0                     2.0
# 7370                         4.0                     2.0
# 7447                         5.0                     2.0
# 7866                         6.0                     3.0
# 8014                         7.0                     3.0
# 9427                         8.0                     4.0
# 10862                        9.0                     5.0
# 11271                       10.0                     5.0
# 11621                       11.0                     5.0
#
#       timefeature_totalreferralsforclient
# 6126                                   11
# 6923                                   11
# 7250                                   11
# 7370                                   11
# 7447                                   11
# 7866                                   11
# 8014                                   11
# 9427                                   11
# 10862                                  11
# 11271                                  11
# 11621                                  11
#
# [11 rows x 28 columns]

# %%
tables = construct_full_tables(json_data)

# %%
json_data[1]
# Out:
# {'client': [{'addressline2': None,
#    'addressline4': None,
#    'addresslocalityid': 11,
#    'addresspostcode': 'HD2 2',
#    'addresssincedate': '06/12/14 00:00:00',
#    'clientaddresstypeid': 1,
#    'clientcountryid': None,
#    'clientdateofbirth': '06/01/71 00:00:00',
#    'clientethnicityid': 10,
#    'clientid': 13,
#    'clientismale': '0',
#    'clientresidencyid': None,
#    'dependantnumber': 2,
#    'enabled': '1',
#    'lastmodifieddate': '09/11/15 00:00:00',
#    'lastmodifiedworkerid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'updatetimestamp': '09/11/15 10:22:29'}],
#  'clientissue': [],
#  'referral': [{'addresslocalityid': 11,
#    'addresstypeid': 1,
#    'clientid': 13,
#    'dependantnumber': 2,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 77,
#    'referralcollecteddate': '02/05/14 00:00:00',
#    'referralhandedworkerid': None,
#    'referralinstanceid': 18,
#    'referralpreparedworkerid': None,
#    'referralreadydate': '02/05/14 00:00:00',
#    'referraltakendate': '02/05/14 00:00:00',
#    'referralworkerid': 4,
#    'statusid': 3,
#    'updatetimestamp': '04/01/14 09:54:22'},
#   {'addresslocalityid': 11,
#    'addresstypeid': 1,
#    'clientid': 13,
#    'dependantnumber': 2,
#    'ethnicityid': 10,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 86,
#    'referralcollecteddate': '09/11/15 00:00:00',
#    'referralhandedworkerid': 1,
#    'referralinstanceid': 9083,
#    'referralpreparedworkerid': 1,
#    'referralreadydate': '09/11/15 00:00:00',
#    'referraltakendate': '09/11/15 10:25:00',
#    'referralworkerid': 1,
#    'statusid': 3,
#    'updatetimestamp': '09/15/15 10:57:07'}],
#  'referralbenefit': [],
#  'referraldietaryrequirements': [{'dietaryrequirementsid': 2,
#    'referralinstanceid': 9083}],
#  'referraldocument': [],
#  'referraldomesticcircumstances': [{'domesticcircumstancesid': 6,
#    'referralinstanceid': 9083}],
#  'referralissue': [],
#  'referralreason': [{'referralinstanceid': 9083, 'referralreasonid': 26}]}

# %%
[t.columns for k,t in tables.items()]
# Out:
# [Index(['domesticcircumstancesid', 'referralinstanceid'], dtype='object'),
#  Index(['clientissueid', 'referralinstanceid'], dtype='object'),
#  Index(['clientid', 'clientissueid'], dtype='object'),
#  Index(['referralinstanceid', 'referralreasonid'], dtype='object'),
#  Index(['dietaryrequirementsid', 'referralinstanceid'], dtype='object'),
#  Index(['benefittypeid', 'referralinstanceid'], dtype='object'),
#  Index(['addressline2', 'addressline4', 'addresslocalityid', 'addresspostcode',
#         'addresssincedate', 'clientaddresstypeid', 'clientcountryid',
#         'clientdateofbirth', 'clientethnicityid', 'clientid', 'clientismale',
#         'clientresidencyid', 'dependantnumber', 'enabled', 'lastmodifieddate',
#         'lastmodifiedworkerid', 'livingwithpartner', 'partnerid',
#         'updatetimestamp'],
#        dtype='object'),
#  Index(['referraldocumentid', 'referralinstanceid'], dtype='object'),
#  Index(['addresslocalityid', 'addresstypeid', 'clientid', 'dependantnumber',
#         'ethnicityid', 'livingwithpartner', 'partnerid', 'referralagencyid',
#         'referralcollecteddate', 'referralhandedworkerid', 'referralinstanceid',
#         'referralpreparedworkerid', 'referralreadydate', 'referraltakendate',
#         'referralworkerid', 'statusid', 'updatetimestamp'],
#        dtype='object')]

# %%
X, y, referral_table, model, message = train_model_from_json(json_tables)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c8f4e8b890a4> in <module>()
# ----> 1 X, y, referral_table, model, message = train_model_from_json(json_tables)
#
# ~/Git-repos/welcome-centre/Welcome-Centre-DataCorps-Code/twc_api/api/resources/retrain.py in train_model_from_json(json_data)
#      14 def train_model_from_json(json_data):
#      15     summary_statuses = []
# ---> 16     tables = construct_full_tables(json_data)
#      17     # Generate feature matrix and target vector
#      18     X, y, referral_table, generation_summary = generate_X_y(tables)
#
# ~/Git-repos/welcome-centre/Welcome-Centre-DataCorps-Code/twc_api/api/resources/retrain.py in construct_full_tables(json_data)
#      55     for row in json_data:
#      56         for key in row:
# ---> 57             tables[key].append(pd.DataFrame.from_dict(row[key]))
#      58     return {k: pd.concat(v) for k, v in tables.items()}
#      59
#
# TypeError: string indices must be integers

# %%
with open('../twc_api/api/requestNewData.json', 'r') as f:
    json_data = json.load(f)
# X, y, referral_table, model, message = train_model_from_json(json_data)

# %%
json_data[0]
# Out:
# {'client': [{'addressline2': None,
#    'addressline4': None,
#    'addresslocalityid': None,
#    'addresspostcode': 'HD1 5',
#    'addresssincedate': '12/02/16 00:00:00',
#    'clientaddresstypeid': 2,
#    'clientcountryid': None,
#    'clientdateofbirth': '03/01/68 00:00:00',
#    'clientethnicityid': 1,
#    'clientid': 10,
#    'clientismale': '1',
#    'clientresidencyid': None,
#    'dependantnumber': 0,
#    'enabled': '1',
#    'lastmodifieddate': '12/02/16 00:00:00',
#    'lastmodifiedworkerid': 8,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'updatetimestamp': '12/02/16 14:06:17'}],
#  'clientissue': [{'clientid': 10, 'clientissueid': 9}],
#  'referral': [{'addresslocalityid': 6,
#    'addresstypeid': 4,
#    'clientid': 10,
#    'dependantnumber': 0,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 31,
#    'referralcollecteddate': '01/13/14 00:00:00',
#    'referralhandedworkerid': None,
#    'referralinstanceid': 12,
#    'referralpreparedworkerid': None,
#    'referralreadydate': '01/13/14 00:00:00',
#    'referraltakendate': '01/13/14 00:00:00',
#    'referralworkerid': 4,
#    'statusid': 3,
#    'updatetimestamp': '04/01/14 09:53:43'},
#   {'addresslocalityid': 6,
#    'addresstypeid': 1,
#    'clientid': 10,
#    'dependantnumber': 0,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 86,
#    'referralcollecteddate': '02/03/14 00:00:00',
#    'referralhandedworkerid': None,
#    'referralinstanceid': 13,
#    'referralpreparedworkerid': None,
#    'referralreadydate': '02/03/14 00:00:00',
#    'referraltakendate': '02/03/14 00:00:00',
#    'referralworkerid': 4,
#    'statusid': 3,
#    'updatetimestamp': '04/01/14 09:53:43'},
#   {'addresslocalityid': 6,
#    'addresstypeid': 1,
#    'clientid': 10,
#    'dependantnumber': 0,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 32,
#    'referralcollecteddate': '06/09/14 15:31:00',
#    'referralhandedworkerid': 7,
#    'referralinstanceid': 2631,
#    'referralpreparedworkerid': 7,
#    'referralreadydate': '06/09/14 15:31:00',
#    'referraltakendate': '06/09/14 15:31:00',
#    'referralworkerid': 7,
#    'statusid': 3,
#    'updatetimestamp': '06/09/14 15:31:52'},
#   {'addresslocalityid': 6,
#    'addresstypeid': 1,
#    'clientid': 10,
#    'dependantnumber': 0,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 86,
#    'referralcollecteddate': '06/16/14 15:46:00',
#    'referralhandedworkerid': 7,
#    'referralinstanceid': 2733,
#    'referralpreparedworkerid': 7,
#    'referralreadydate': '06/16/14 15:46:00',
#    'referraltakendate': '06/16/14 15:46:00',
#    'referralworkerid': 7,
#    'statusid': 3,
#    'updatetimestamp': '06/16/14 15:46:05'},
#   {'addresslocalityid': 6,
#    'addresstypeid': 1,
#    'clientid': 10,
#    'dependantnumber': 0,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 86,
#    'referralcollecteddate': '06/23/14 16:42:00',
#    'referralhandedworkerid': 7,
#    'referralinstanceid': 2873,
#    'referralpreparedworkerid': 7,
#    'referralreadydate': '06/23/14 16:42:00',
#    'referraltakendate': '06/23/14 16:42:00',
#    'referralworkerid': 7,
#    'statusid': 3,
#    'updatetimestamp': '06/23/14 16:42:17'},
#   {'addresslocalityid': 6,
#    'addresstypeid': 4,
#    'clientid': 10,
#    'dependantnumber': 0,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 65,
#    'referralcollecteddate': '10/18/16 13:06:00',
#    'referralhandedworkerid': 26,
#    'referralinstanceid': 14956,
#    'referralpreparedworkerid': 26,
#    'referralreadydate': '10/18/16 13:06:00',
#    'referraltakendate': '10/18/16 11:24:00',
#    'referralworkerid': 15,
#    'statusid': 3,
#    'updatetimestamp': '10/18/16 13:06:42'},
#   {'addresslocalityid': None,
#    'addresstypeid': 4,
#    'clientid': 10,
#    'dependantnumber': 0,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 89,
#    'referralcollecteddate': '11/08/16 16:46:00',
#    'referralhandedworkerid': 1,
#    'referralinstanceid': 15293,
#    'referralpreparedworkerid': 1,
#    'referralreadydate': '11/08/16 16:46:00',
#    'referraltakendate': '11/08/16 12:32:00',
#    'referralworkerid': 1,
#    'statusid': 3,
#    'updatetimestamp': '11/08/16 16:46:33'},
#   {'addresslocalityid': None,
#    'addresstypeid': 2,
#    'clientid': 10,
#    'dependantnumber': 0,
#    'ethnicityid': 1,
#    'livingwithpartner': '0',
#    'partnerid': None,
#    'referralagencyid': 136,
#    'referralcollecteddate': '12/02/16 15:29:00',
#    'referralhandedworkerid': 26,
#    'referralinstanceid': 15739,
#    'referralpreparedworkerid': 26,
#    'referralreadydate': '12/02/16 15:29:00',
#    'referraltakendate': '12/02/16 14:09:00',
#    'referralworkerid': 8,
#    'statusid': 3,
#    'updatetimestamp': '12/02/16 15:29:51'}],
#  'referralbenefit': [{'benefittypeid': 2, 'referralinstanceid': 15739}],
#  'referraldietaryrequirements': [],
#  'referraldocument': [],
#  'referraldomesticcircumstances': [{'domesticcircumstancesid': 5,
#    'referralinstanceid': 2631},
#   {'domesticcircumstancesid': 6, 'referralinstanceid': 2733},
#   {'domesticcircumstancesid': 5, 'referralinstanceid': 2873},
#   {'domesticcircumstancesid': 6, 'referralinstanceid': 2873},
#   {'domesticcircumstancesid': 6, 'referralinstanceid': 15293},
#   {'domesticcircumstancesid': 6, 'referralinstanceid': 15739}],
#  'referralissue': [{'clientissueid': 9, 'referralinstanceid': 15293}],
#  'referralreason': [{'referralinstanceid': 2631, 'referralreasonid': 29},
#   {'referralinstanceid': 2733, 'referralreasonid': 29},
#   {'referralinstanceid': 2873, 'referralreasonid': 29},
#   {'referralinstanceid': 14956, 'referralreasonid': 43},
#   {'referralinstanceid': 15293, 'referralreasonid': 29},
#   {'referralinstanceid': 15293, 'referralreasonid': 56},
#   {'referralinstanceid': 15739, 'referralreasonid': 29}]}

# %%
from collections import defaultdict
def construct_full_tables(json_data):
    tables = defaultdict(list)
    for row in json_data:
        for key in row:
            tables[key].append(pd.DataFrame.from_dict(row[key]))
    return {k: pd.concat(v) for k, v in tables.items()}

tables = construct_full_tables(json_data)

# %%
tables['refe']

# %%
tables['client'].groupby('clientcountryid').size().sum()
# Out:
# 641

# %%
client_old = training_data['client'].set_index('clientid')
client_new = tables['client'].set_index('clientid')

# %%
client_new['clientaddresstypeid'].value_counts(), client_old['clientaddresstypeid'].value_counts()
# Out:
# (1    2564
#  2     719
#  3     145
#  4     104
#  6     103
#  7      85
#  8      46
#  5      45
#  Name: clientaddresstypeid, dtype: int64, 1.0    3545
#  2.0     838
#  nan     576
#  4.0     179
#  6.0     168
#  3.0     159
#  7.0     116
#  8.0      70
#  5.0      40
#  Name: clientaddresstypeid, dtype: int64)

# %%
tables['referraldocument']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
old_nulls = client_old[client_old['clientcountryid'] == 'nan']

client_new.loc[old_nulls.index].groupby("clientcountryid").size()
# Out:
# /Users/davidsykes/.virtualenvs/twc/lib/python3.5/site-packages/ipykernel_launcher.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   This is separate from the ipykernel package so we can avoid doing imports until
# clientcountryid
# 2     1
# 14    2
# 24    1
# dtype: int64

# %% [markdown]
# ### Find columns that are missing

# %%
len(X_retrain.columns), len(X.columns)
# Out:
# (569, 593)

# %%
[c for c in X.columns if c not in X_retrain.columns]
# Out:
# ['referraldietaryrequirements_1',
#  'referraldietaryrequirements_2',
#  'referraldietaryrequirements_3',
#  'referraldietaryrequirements_4',
#  'referraldietaryrequirements_5',
#  'referraldietaryrequirements_6',
#  'referraldietaryrequirements_7',
#  'referraldietaryrequirements_8',
#  'referraldietaryrequirements_9',
#  'referraldietaryrequirements_10',
#  'referraldietaryrequirements_11',
#  'referraldietaryrequirements_12',
#  'referraldocument_1',
#  'referraldocument_2',
#  'referraldocument_3',
#  'referraldocument_4',
#  'referraldocument_5',
#  'client_clientethnicityid_1.0',
#  'client_clientethnicityid_10.0',
#  'client_clientethnicityid_11.0',
#  'client_clientethnicityid_12.0',
#  'client_clientethnicityid_13.0',
#  'client_clientethnicityid_14.0',
#  'client_clientethnicityid_15.0',
#  'client_clientethnicityid_16.0',
#  'client_clientethnicityid_17.0',
#  'client_clientethnicityid_18.0',
#  'client_clientethnicityid_2.0',
#  'client_clientethnicityid_3.0',
#  'client_clientethnicityid_4.0',
#  'client_clientethnicityid_5.0',
#  'client_clientethnicityid_6.0',
#  'client_clientethnicityid_7.0',
#  'client_clientethnicityid_8.0',
#  'client_clientethnicityid_9.0',
#  'client_clientethnicityid_nan',
#  'client_clientcountryid_1.0',
#  'client_clientcountryid_10.0',
#  'client_clientcountryid_11.0',
#  'client_clientcountryid_12.0',
#  'client_clientcountryid_13.0',
#  'client_clientcountryid_14.0',
#  'client_clientcountryid_15.0',
#  'client_clientcountryid_16.0',
#  'client_clientcountryid_17.0',
#  'client_clientcountryid_18.0',
#  'client_clientcountryid_19.0',
#  'client_clientcountryid_2.0',
#  'client_clientcountryid_20.0',
#  'client_clientcountryid_21.0',
#  'client_clientcountryid_22.0',
#  'client_clientcountryid_23.0',
#  'client_clientcountryid_24.0',
#  'client_clientcountryid_25.0',
#  'client_clientcountryid_26.0',
#  'client_clientcountryid_27.0',
#  'client_clientcountryid_28.0',
#  'client_clientcountryid_29.0',
#  'client_clientcountryid_3.0',
#  'client_clientcountryid_30.0',
#  'client_clientcountryid_4.0',
#  'client_clientcountryid_5.0',
#  'client_clientcountryid_6.0',
#  'client_clientcountryid_7.0',
#  'client_clientcountryid_8.0',
#  'client_clientcountryid_9.0',
#  'client_clientcountryid_nan',
#  'client_clientaddresstypeid_1.0',
#  'client_clientaddresstypeid_2.0',
#  'client_clientaddresstypeid_3.0',
#  'client_clientaddresstypeid_4.0',
#  'client_clientaddresstypeid_5.0',
#  'client_clientaddresstypeid_6.0',
#  'client_clientaddresstypeid_7.0',
#  'client_clientaddresstypeid_8.0',
#  'client_clientaddresstypeid_nan',
#  'client_addresspostcode_ HD6 ',
#  'client_addresspostcode_BD11 ',
#  'client_addresspostcode_HD! 4',
#  'client_addresspostcode_HD1 8',
#  'client_addresspostcode_HD1 D',
#  'client_addresspostcode_HD1 H',
#  'client_addresspostcode_HD2 6',
#  'client_addresspostcode_HD2 7',
#  'client_addresspostcode_HD2 Q',
#  'client_addresspostcode_HD2 Z',
#  'client_addresspostcode_HD21P',
#  'client_addresspostcode_HD22S',
#  'client_addresspostcode_HD3 ',
#  'client_addresspostcode_HD3 7',
#  'client_addresspostcode_HD34D',
#  'client_addresspostcode_HD34Q',
#  'client_addresspostcode_HD34X',
#  'client_addresspostcode_HD4 2',
#  'client_addresspostcode_HD4 S',
#  'client_addresspostcode_HD45L',
#  'client_addresspostcode_HD45T',
#  'client_addresspostcode_HD5 O',
#  'client_addresspostcode_HD56L',
#  'client_addresspostcode_HD58H',
#  'client_addresspostcode_HD59S',
#  'client_addresspostcode_HD59X',
#  'client_addresspostcode_HD6 1',
#  'client_addresspostcode_HD74N',
#  'client_addresspostcode_HD88S',
#  'client_addresspostcode_HD9 ',
#  'client_addresspostcode_HD93E',
#  'client_addresspostcode_HG5 9',
#  'client_addresspostcode_HS2 1',
#  'client_addresspostcode_HX5 0',
#  'client_addresspostcode_WF 12',
#  'client_addresspostcode_WF13',
#  'client_addresspostcode_WF15',
#  'client_addresslocalityid_1.0',
#  'client_addresslocalityid_10.0',
#  'client_addresslocalityid_100.0',
#  'client_addresslocalityid_101.0',
#  'client_addresslocalityid_102.0',
#  'client_addresslocalityid_103.0',
#  'client_addresslocalityid_105.0',
#  'client_addresslocalityid_107.0',
#  'client_addresslocalityid_108.0',
#  'client_addresslocalityid_109.0',
#  'client_addresslocalityid_11.0',
#  'client_addresslocalityid_110.0',
#  'client_addresslocalityid_111.0',
#  'client_addresslocalityid_112.0',
#  'client_addresslocalityid_115.0',
#  'client_addresslocalityid_116.0',
#  'client_addresslocalityid_117.0',
#  'client_addresslocalityid_119.0',
#  'client_addresslocalityid_12.0',
#  'client_addresslocalityid_120.0',
#  'client_addresslocalityid_121.0',
#  'client_addresslocalityid_124.0',
#  'client_addresslocalityid_125.0',
#  'client_addresslocalityid_128.0',
#  'client_addresslocalityid_130.0',
#  'client_addresslocalityid_131.0',
#  'client_addresslocalityid_133.0',
#  'client_addresslocalityid_134.0',
#  'client_addresslocalityid_135.0',
#  'client_addresslocalityid_136.0',
#  'client_addresslocalityid_137.0',
#  'client_addresslocalityid_140.0',
#  'client_addresslocalityid_141.0',
#  'client_addresslocalityid_142.0',
#  'client_addresslocalityid_143.0',
#  'client_addresslocalityid_145.0',
#  'client_addresslocalityid_147.0',
#  'client_addresslocalityid_15.0',
#  'client_addresslocalityid_151.0',
#  'client_addresslocalityid_152.0',
#  'client_addresslocalityid_153.0',
#  'client_addresslocalityid_158.0',
#  'client_addresslocalityid_168.0',
#  'client_addresslocalityid_169.0',
#  'client_addresslocalityid_17.0',
#  'client_addresslocalityid_18.0',
#  'client_addresslocalityid_2.0',
#  'client_addresslocalityid_20.0',
#  'client_addresslocalityid_23.0',
#  'client_addresslocalityid_26.0',
#  'client_addresslocalityid_27.0',
#  'client_addresslocalityid_29.0',
#  'client_addresslocalityid_3.0',
#  'client_addresslocalityid_30.0',
#  'client_addresslocalityid_31.0',
#  'client_addresslocalityid_32.0',
#  'client_addresslocalityid_33.0',
#  'client_addresslocalityid_35.0',
#  'client_addresslocalityid_36.0',
#  'client_addresslocalityid_37.0',
#  'client_addresslocalityid_38.0',
#  'client_addresslocalityid_42.0',
#  'client_addresslocalityid_43.0',
#  'client_addresslocalityid_45.0',
#  'client_addresslocalityid_47.0',
#  'client_addresslocalityid_5.0',
#  'client_addresslocalityid_50.0',
#  'client_addresslocalityid_51.0',
#  'client_addresslocalityid_52.0',
#  'client_addresslocalityid_53.0',
#  'client_addresslocalityid_55.0',
#  'client_addresslocalityid_56.0',
#  'client_addresslocalityid_58.0',
#  'client_addresslocalityid_6.0',
#  'client_addresslocalityid_61.0',
#  'client_addresslocalityid_63.0',
#  'client_addresslocalityid_64.0',
#  'client_addresslocalityid_67.0',
#  'client_addresslocalityid_69.0',
#  'client_addresslocalityid_72.0',
#  'client_addresslocalityid_74.0',
#  'client_addresslocalityid_75.0',
#  'client_addresslocalityid_76.0',
#  'client_addresslocalityid_77.0',
#  'client_addresslocalityid_79.0',
#  'client_addresslocalityid_8.0',
#  'client_addresslocalityid_80.0',
#  'client_addresslocalityid_82.0',
#  'client_addresslocalityid_83.0',
#  'client_addresslocalityid_84.0',
#  'client_addresslocalityid_85.0',
#  'client_addresslocalityid_87.0',
#  'client_addresslocalityid_88.0',
#  'client_addresslocalityid_89.0',
#  'client_addresslocalityid_91.0',
#  'client_addresslocalityid_92.0',
#  'client_addresslocalityid_93.0',
#  'client_addresslocalityid_95.0',
#  'client_addresslocalityid_96.0',
#  'client_addresslocalityid_98.0',
#  'client_addresslocalityid_nan',
#  'client_clientresidencyid_1.0',
#  'client_clientresidencyid_2.0',
#  'client_clientresidencyid_3.0',
#  'client_clientresidencyid_4.0',
#  'client_clientresidencyid_5.0',
#  'client_clientresidencyid_6.0',
#  'client_clientresidencyid_7.0',
#  'client_clientresidencyid_nan',
#  'clientissue_5',
#  'clientissue_14']

# %%
y_pred = pd.Series(model.predict(X_test), X_test.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d04e26bfc8b8> in <module>()
# ----> 1 y_pred = pd.Series(model.predict(X_test), X_test.index)
#
# ~/.virtualenvs/twc/lib/python3.5/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     679         check_is_fitted(self, 'estimators_')
#     680         # Check data
# --> 681         X = self._validate_X_predict(X)
#     682
#     683         # Assign chunk of trees to jobs
#
# ~/.virtualenvs/twc/lib/python3.5/site-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
#     355                                  "call `fit` before exploiting the model.")
#     356
# --> 357         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     358
#     359     @property
#
# ~/.virtualenvs/twc/lib/python3.5/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     382                              "match the input. Model n_features is %s and "
#     383                              "input n_features is %s "
# --> 384                              % (self.n_features_, n_features))
#     385
#     386         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 569 and input n_features is 593

# %%
print(message)
# Out:
# Features Matrix generated consisting of 21181 referrals and 569 features
# Train/Test sets split.
# Train set: 16944 referrals.
# Test set: 4237 referrals
# Trained Model on: 16944 observations
# Model Test Evaluation Metrics:
# 	Test Set Correlation of Predicted and Actual Mean Weekly Scores: 0.285111297280371
# 	Test Set Overlap of top 20.0% worst cases: 0.23163067552602426
# Trained Model on: 21181 observations
